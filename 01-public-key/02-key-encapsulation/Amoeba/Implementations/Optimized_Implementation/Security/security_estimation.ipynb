# %%
#SageMath
from estimator import *

# %%
N = 288
Q = 3457

argList = {
    128: [N*2, 2, 2],
    192: [N*3, 1, 2],
    256: [N*4, 1, 1],
    384: [N*6, 1, 1],
    512: [N*8, 1, 1],
}

ss = lambda b: (b*0.2925, b*0.2563, b*0.2075)

# %%
# 128-bit

args = argList[128]
params = LWE.Parameters(n=args[0], q=Q, Xs=ND.CenteredBinomial(args[1]), Xe=ND.CenteredBinomial(args[2]))
res = LWE.estimate.rough(params, jobs=16)
# Out:
# usvp                 :: rop: ≈2^128.2, red: ≈2^128.2, δ: 1.003732, β: 439, d: 1094, tag: usvp
# dual_hybrid          :: rop: ≈2^123.9, red: ≈2^123.8, guess: ≈2^119.0, β: 424, p: 4, ζ: 0, t: 50, β': 424, N: ≈2^87.6, m: 576
# arora-gb             :: rop: ≈2^78.0, dreg: 5, mem: ≈2^78.0, t: 2, m: ≈2^39.0

# %%
res = LWE.estimate(params, jobs=16)
# Out:
# arora-gb             :: rop: ≈2^80.3, dreg: 5, mem: ≈2^77.9, t: 2, m: ≈2^41.3, tag: arora-gb, ↻: 5, ζ: 1
# bkw                  :: rop: ≈2^168.6, m: ≈2^156.2, mem: ≈2^157.2, b: 13, t1: 4, t2: 17, ℓ: 12, #cod: 459, #top: 0, #test: 67, tag: coded-bkw
# usvp                 :: rop: ≈2^153.1, red: ≈2^153.1, δ: 1.003732, β: 439, d: 1094, tag: usvp
# bdd                  :: rop: ≈2^149.6, red: ≈2^148.7, svp: ≈2^148.5, β: 423, η: 456, d: 1089, tag: bdd
# dual                 :: rop: ≈2^159.5, mem: ≈2^103.9, m: 564, β: 458, d: 1140, ↻: 1, tag: dual
# dual_hybrid          :: rop: ≈2^147.2, red: ≈2^146.7, guess: ≈2^145.5, β: 412, p: 4, ζ: 20, t: 40, β': 415, N: ≈2^86.0, m: 576

# %%
ss(439)
# Out:
# (128.4075, 112.51569999999998, 91.0925)

# %%
# 192-bit

args = argList[192]
params = LWE.Parameters(n=args[0], q=Q, Xs=ND.CenteredBinomial(args[1]), Xe=ND.CenteredBinomial(args[2]))
res = LWE.estimate.rough(params, jobs=16)
# Out:
# usvp                 :: rop: ≈2^198.0, red: ≈2^198.0, δ: 1.002731, β: 678, d: 1528, tag: usvp
# dual_hybrid          :: rop: ≈2^185.8, red: ≈2^185.7, guess: ≈2^182.0, β: 636, p: 3, ζ: 20, t: 80, β': 636, N: ≈2^131.9, m: 864
# arora-gb             :: rop: ≈2^83.8, dreg: 5, mem: ≈2^83.8, t: 2, m: ≈2^41.9

# %%
res = LWE.estimate(params, jobs=16)
# Out:
# arora-gb             :: rop: ≈2^83.8, dreg: 5, mem: ≈2^83.8, t: 2, m: ≈2^41.9, tag: arora-gb, ↻: 1, ζ: 0
# bkw                  :: rop: ≈2^218.5, m: ≈2^204.7, mem: ≈2^204.4, b: 17, t1: 5, t2: 18, ℓ: 16, #cod: 670, #top: 2, #test: 107, tag: coded-bkw
# usvp                 :: rop: ≈2^220.1, red: ≈2^220.1, δ: 1.002731, β: 678, d: 1528, tag: usvp
# bdd                  :: rop: ≈2^216.1, red: ≈2^215.1, svp: ≈2^215.1, β: 660, η: 695, d: 1520, tag: bdd
# dual                 :: rop: ≈2^230.2, mem: ≈2^154.1, m: 736, β: 710, d: 1600, ↻: 1, tag: dual
# dual_hybrid          :: rop: ≈2^207.6, red: ≈2^207.5, guess: ≈2^200.2, β: 629, p: 3, ζ: 30, t: 80, β': 620, N: ≈2^128.6, m: 864

# %%
ss(678)
# Out:
# (198.315, 173.77139999999997, 140.685)

# %%
# 256-bit

args = argList[256]
params = LWE.Parameters(n=args[0], q=Q, Xs=ND.CenteredBinomial(args[1]), Xe=ND.CenteredBinomial(args[2]))
res = LWE.estimate.rough(params, jobs=16)
# Out:
# usvp                 :: rop: ≈2^266.0, red: ≈2^266.0, δ: 1.002192, β: 911, d: 2015, tag: usvp
# dual_hybrid          :: rop: ≈2^248.7, red: ≈2^248.5, guess: ≈2^245.9, β: 851, p: 3, ζ: 20, t: 120, β': 851, N: ≈2^176.3, m: 1152
# arora-gb             :: rop: ≈2^55.9, dreg: 3, mem: ≈2^55.9, t: 1, m: ≈2^27.9

# %%
res = LWE.estimate(params, jobs=16)
# Out:
# arora-gb             :: rop: ≈2^57.4, dreg: 3, mem: ≈2^55.9, t: 1, m: ≈2^29.5, tag: arora-gb, ↻: 3, ζ: 1
# bkw                  :: rop: ≈2^287.2, m: ≈2^273.8, mem: ≈2^274.8, b: 23, t1: 2, t2: 19, ℓ: 22, #cod: 953, #top: 0, #test: 155, tag: coded-bkw
# usvp                 :: rop: ≈2^285.7, red: ≈2^285.7, δ: 1.002192, β: 911, d: 2015, tag: usvp
# bdd                  :: rop: ≈2^281.3, red: ≈2^280.4, svp: ≈2^280.3, β: 892, η: 928, d: 2024, tag: bdd
# dual                 :: rop: ≈2^299.0, mem: ≈2^202.6, m: 956, β: 955, d: 2108, ↻: 1, tag: dual
# dual_hybrid          :: rop: ≈2^268.5, red: ≈2^268.1, guess: ≈2^266.5, β: 844, p: 3, ζ: 40, t: 110, β': 825, N: ≈2^170.4, m: 1152

# %%
ss(911)
# Out:
# (266.4675, 233.4893, 189.0325)

# %%
# 384-bit

args = argList[384]
params = LWE.Parameters(n=args[0], q=Q, Xs=ND.CenteredBinomial(args[1]), Xe=ND.CenteredBinomial(args[2]))
res = LWE.estimate.rough(params, jobs=16)
# Out:
# usvp                 :: rop: ≈2^423.1, red: ≈2^423.1, δ: 1.001537, β: 1449, d: 2975, tag: usvp
# dual_hybrid          :: rop: ≈2^393.7, red: ≈2^393.6, guess: ≈2^389.4, β: 1348, p: 3, ζ: 20, t: 210, β': 1348, N: ≈2^279.4, m: 1728
# arora-gb             :: rop: ≈2^59.4, dreg: 3, mem: ≈2^59.4, t: 1, m: ≈2^29.7

# %%
res = LWE.estimate(params, jobs=16)
# Out:
# arora-gb             :: rop: ≈2^60.9, dreg: 3, mem: ≈2^59.4, t: 1, m: ≈2^31.3, tag: arora-gb, ↻: 3, ζ: 1
# bkw                  :: rop: ≈2^405.7, m: ≈2^391.5, mem: ≈2^392.5, b: 33, t1: 5, t2: 19, ℓ: 32, #cod: 1350, #top: 0, #test: 217, tag: coded-bkw
# usvp                 :: rop: ≈2^437.2, red: ≈2^437.2, δ: 1.001537, β: 1449, d: 2975, tag: usvp
# bdd                  :: rop: ≈2^432.3, red: ≈2^431.3, svp: ≈2^431.4, β: 1428, η: 1466, d: 2981, tag: bdd
# dual                 :: rop: ≈2^459.1, mem: ≈2^315.5, m: 1360, β: 1523, d: 3088, ↻: 1, tag: dual
# dual_hybrid          :: rop: ≈2^409.8, red: ≈2^409.5, guess: ≈2^407.6, β: 1346, p: 3, ζ: 30, t: 210, β': 1302, N: ≈2^269.5, m: 1728

# %%
ss(1449)
# Out:
# (423.8325, 371.3787, 300.66749999999996)

# %%
# 512-bit

args = argList[512]
params = LWE.Parameters(n=args[0], q=Q, Xs=ND.CenteredBinomial(args[1]), Xe=ND.CenteredBinomial(args[2]))
res = LWE.estimate.rough(params, jobs=16)
# Out:
# usvp                 :: rop: ≈2^584.3, red: ≈2^584.3, δ: 1.001193, β: 2001, d: 3959, tag: usvp
# arora-gb             :: rop: ≈2^61.9, dreg: 3, mem: ≈2^61.9, t: 1, m: ≈2^30.9

# %%
res = LWE.estimate(params, jobs=16)
# Out:
# arora-gb             :: rop: ≈2^63.4, dreg: 3, mem: ≈2^61.9, t: 1, m: ≈2^32.5, tag: arora-gb, ↻: 3, ζ: 1
# usvp                 :: rop: ≈2^593.0, red: ≈2^593.0, δ: 1.001193, β: 2001, d: 3959, tag: usvp
# bdd                  :: rop: ≈2^587.8, red: ≈2^586.8, svp: ≈2^586.9, β: 1979, η: 2018, d: 3944, tag: bdd
# dual                 :: rop: ≈2^712.4, mem: ≈2^524.9, m: 1701, β: 2047, d: 4005, ↻: 1, tag: dual

# %%
ss(2001)
# Out:
# (585.2925, 512.8562999999999, 415.2075)
