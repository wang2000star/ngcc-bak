# %% [markdown]
# 所有备选素数为：
#
# 1、n = 256 时，所有满足 n|q-1 或 n/2|q-1 的素数 q
#
# [257, 641, 769, 1153, 1409, 2689, 3329, 3457, 4481, 4993, 6529, 7297, 7681, 7937, 9473, 9601, 9857,
# 10369, 10753, 11393, 11777, 12161, 12289, 13313, 13441, 13697, 14081, 14593, 15233, 15361, 16001,
# 17921, 18049, 18433, 19073, 19457, 19841, 20353, 21121, 21377, 22273, 23041, 23297, 25601, 26113,
# 26497, 26881, 28289, 29569, 30593, 30977, 31489, 31873, 32257, 33409, 35201, 35969, 36097, 36353,
# 37633, 37889, 38273, 39041, 39937, 40193, 40577, 40961, 41729, 43649, 43777, 44417, 45569, 45697,
# 45953, 46337, 49409, 49537, 49921, 50177, 51329, 51713, 52609, 53377, 53633, 54401, 55681, 57089,
# 57601, 58369, 59009, 59393, 60161, 60289, 61057, 61441, 62081, 63361, 63617, 64513, 65537, 65921,
# 67073, 68737, 68993, 69761, 70529, 70657, 70913, 71809, 72577, 75521, 76289, 76673, 76801, 77569,
# 78593, 78721, 78977, 79873, 80513, 80897, 81281, 81409, 82561, 83969, 84481, 84737, 85121, 85889,
# 86017, 87041, 87553, 88321, 91009, 91393, 92033, 92801, 94849, 95233, 95617, 95873, 96001, 96769,
# 98561, 98689, 99713, 100609, 101377, 102913, 103553, 103681, 105601, 106753, 107137, 107777, 108161,
# 108289, 108929, 109313, 109441, 110849, 110977, 112129, 113153, 113537, 113921, 114689, 115201,
# 116993, 117889, 118273, 118529, 118913, 119297, 119809, 120193, 120577, 120833, 122497, 122753,
# 124673, 125441, 126337, 127873, 128257, 129281, 129793, 130817, 131713, 131969, 133121, 133633,
# 134401, 135937, 136193, 137089, 138113, 138241, 138497, 139393]
#
#
# 2、n = 512 时，所有满足 n|q-1 或 n/2|q-1 的素数 q
#
# [257, 769, 3329, 7681, 7937, 9473, 10753, 11777, 12289, 13313, 14081, 14593, 15361, 17921, 18433,
# 19457, 22273, 23041, 23297, 25601, 26113, 26881, 30977, 31489, 32257, 36097, 36353, 37633, 37889,
# 39937, 40193, 40961, 41729, 43777, 45569, 46337, 49409, 49921, 50177, 51713, 57089, 57601, 58369,
# 59393, 60161, 61441, 64513, 65537, 67073, 70657, 70913, 75521, 76289, 76801, 77569, 78593, 79873,
# 80897, 81409, 83969, 84481, 84737, 86017, 87041, 87553, 88321, 91393, 95233, 96001, 96769, 98561,
# 100609, 101377, 102913, 103681, 106753, 107777, 108289, 109313, 110849, 112129, 113153, 113921, 114689,
# 115201, 116993, 118273, 118529, 119297, 119809, 120577, 120833, 124673, 125441, 128257, 129281, 129793,
# 130817, 133121, 133633, 134401, 135937, 136193, 138241, 138497]
#
#
# 3、n = 1024 时，所有满足 n|q-1 或 n/2|q-1 的素数 q
#
# [7681, 10753, 11777, 12289, 13313, 15361, 17921, 18433, 19457, 23041, 25601, 26113, 32257, 36353,
# 37889, 39937, 40961, 45569, 50177, 51713, 58369, 59393, 61441, 64513, 65537, 67073, 70657, 76289,
# 76801, 79873, 80897, 81409, 83969, 84481, 86017, 87041, 87553, 95233, 96769, 101377, 102913, 112129,
# 113153, 114689, 115201, 118273, 119297, 119809, 120833, 125441, 133121, 133633, 136193, 138241, 143873,
# 147457, 151553, 153089, 155137, 158209, 159233, 161281, 163841, 168449, 170497, 176129, 176641, 183809,
# 184321, 187393, 188417, 202753, 211457, 211969, 216577, 219649, 220673, 226817, 228353, 232961, 235009,
# 238081, 240641, 242689, 249857, 251393, 254977, 260609, 262657, 265729, 270337, 275969, 278017, 279553,
# 284161, 285697, 286721, 287233, 288257, 295937, 299521, 301057, 302593, 303617, 306689, 307201, 310273,
# 319489, 320513, 324097, 326657, 329729, 330241, 331777, 340481, 345089, 345601, 349697, 355841, 357377,
# 365569, 366593, 368129, 380417, 380929, 383489, 384001, 385537, 394241, 403969, 414209, 414721, 416257,
# 417793, 419329, 420353, 424961, 425473, 428033, 430081, 431617, 434689, 444929, 455681, 456193, 460289,
# 462337, 463873, 464897, 471041, 471553, 473089, 475649, 495617, 497153, 498689, 503297, 509441, 514049,
# 514561, 518657, 520193, 523777, 524801, 525313]

# %%
# 128 bits 安全性参数

from math import sqrt
from Sign_estimate import *
from helper_pycode.repetitions_compute import * 
from helper_pycode.gamma_estimate import gamma_estimate
from helper_pycode.tau_compute import tau_computer

##############################################################
# 参数
n    =  512         # 环的维数
k    =  1           # 矩阵 A 的参数（A的行数为  k ）
l    =  2           # 矩阵 A 的参数（A的列数为 l-1）
q    =  130817      # 模数
p    =  0.15        # 三元分布取 1（或-1）的概率
c_entropy = 161     # c 的信息熵大小
tau  =  tau_computer(n, c_entropy)         
                    # c 的汉明重量（根据需要提前计算得到）
N    =  10000       # 估计 gamma 时的重复次数，N 越大估计越准确
rate =  [50]        # s 的通过率（可自由设定，仅可设定一个）
B11  =  7500        # 界的参数（其余的界由这个设定的计算得到）
d    =  10          # 压缩后的 比特 数

# 以上为可改动的参数！！！
##############################################################

print("128 bits security parameters:")
print("-------------------------------")
dim  = k + l        # s 的维数
num1 = int(n * p)   # 三元分布中 1（或-1）的个数

# gamma 和 Sc 的估计
gamma = gamma_estimate(N, n, num1, dim, tau, rate)[0]
t = float(gamma * sqrt(tau))
print(f"gamma          =  {gamma}")
print(f"tau            =  {tau}")
print(f"entropy of c   =  {c_entropy}")
print(f"bound of Sc    =  {t}")

print("-------------------------------")

# 相关的界
B     = from_B11_to_B(B11, n, k, l, q, d, t)
B0    = from_B11_to_B0(B11, n, k, l, q, d, t)
B1    = from_B11_to_B1(B11, n, k, l, q, d)
B_SIS = from_B11_to_BSIS(B11, n, k, l, q, d)
print(f"B11            =  {B11}")
print(f"B0             =  {B0}")
print(f"B1             =  {B1}")
print(f"B              =  {B}")
print(f"B_SIS          =  {B_SIS}")

print("-------------------------------")

# 采样次数
M_reject , M_compress, M = from_B11_to_M(B11, n, k, l, q, d, tau, t)
print(f"sk accept rate =  {rate[0]}")
print(f"M_reject       =  {M_reject}")
print(f"M_compress     =  {M_compress}")
print(f"M              =  {M}")

print("-------------------------------")

# 安全性 和 尺寸
try_parameter = SignParameters(n, k, l, q, p, tau, d, B11, t)
summarize_sign(try_parameter)
# Out:
# 128 bits security parameters:
# -------------------------------
# gamma          =  34.9291456179819
# tau            =  30
# entropy of c   =  161
# bound of Sc    =  191.31480969351415
# -------------------------------
# B11            =  7500
# B0             =  5858.470875820772
# B1             =  6046.759916206818
# B              =  6049.785685514285
# B_SIS          =  10435.929452573459
# -------------------------------
# sk accept rate =  50
# M_reject       =  4.312690194377087
# M_compress     =  1.117334933267475
# M              =  4.818719410537615
# -------------------------------
# Sign parameters: {'n': 512, 'k': 1, 'l': 2, 'q': 130817, 'p': 0.15, 'tau': 30, 'd': 10, 'B11': 7500, 't': 191.31480969351415}
# Bound for SIS: 10435.929452573459
# Public key size (bytes):  1120
# Signature size (bytes):   1542
# Sum size (bytes):         2662
# MLWE security:
# Primal & 509 & 560 & 163 & 143 & 116
# Dual & 511 & 550 & 160 & 141 & 114
# MSIS security:
# ...

# %%
# 256 bits 安全性参数  # tau需要改动，如果n = 256

from math import sqrt
from Sign_estimate import *
from helper_pycode.repetitions_compute import * 
from helper_pycode.gamma_estimate import gamma_estimate
from helper_pycode.tau_compute import tau_computer

##############################################################
# 参数
n    =  512         # 环的维数
k    =  2           # 矩阵 A 的参数（A的行数为  k ）
l    =  3           # 矩阵 A 的参数（A的列数为 l-1）
q    =  130817      # 模数
p    =  0.3125        # 三元分布取 1（或-1）的概率
c_entropy = 257     # c 的信息熵大小
tau  =  tau_computer(n, c_entropy)         
                    # c 的汉明重量（根据需要提前计算得到）
N    =  10000       # 估计 gamma 时的重复次数，N 越大估计越准确
rate =  [50]        # s 的通过率（可自由设定，仅可设定一个）
B11  =  23000       # 界的参数（其余的界由这个设定的计算得到）
d    =  9           # 压缩后的 比特 数

# 以上为可改动的参数！！！
##############################################################

print("256 bits security parameters:")
print("-------------------------------")

dim  = k + l        # s 的维数
num1 = int(n * p)   # 三元分布中 1（或-1）的个数

# gamma 和 Sc 的估计
gamma = gamma_estimate(N, n, num1, dim, tau, rate)[0]
t = float(gamma * sqrt(tau))
print(f"gamma          =  {gamma}")
print(f"tau            =  {tau}")
print(f"entropy of c   =  {c_entropy}")
print(f"bound of Sc    =  {t}")

print("-------------------------------")

# 相关的界
B     = from_B11_to_B(B11, n, k, l, q, d, t)
B0    = from_B11_to_B0(B11, n, k, l, q, d, t)
B1    = from_B11_to_B1(B11, n, k, l, q, d)
B_SIS = from_B11_to_BSIS(B11, n, k, l, q, d)
print(f"B11            =  {B11}")
print(f"B0             =  {B0}")
print(f"B1             =  {B1}")
print(f"B              =  {B}")
print(f"B_SIS          =  {B_SIS}")

print("-------------------------------")

# 采样次数
M_reject, M_compress, M = from_B11_to_M(B11, n, k, l, q, d, tau, t)
print(f"sk accept rate =  {rate[0]}")
print(f"M_reject       =  {M_reject}")
print(f"M_compress     =  {M_compress}")
print(f"M              =  {M}")

print("-------------------------------")

# 安全性 和 尺寸
try_parameter = SignParameters(n, k, l, q, p, tau, d, B11, t)
summarize_sign(try_parameter)
# Out:
# 256 bits security parameters:
# -------------------------------
# gamma          =  62.0022195510692
# tau            =  59
# entropy of c   =  257
# bound of Sc    =  476.2480850631111
# -------------------------------
# B11            =  23000
# B0             =  18429.974128150832
# B1             =  18900.222912360005
# B              =  18906.222213213943
# B_SIS          =  31240.0625
# -------------------------------
# sk accept rate =  50
# M_reject       =  4.506912686998792
# M_compress     =  1.1151722058031421
# M              =  5.025983762522609
# -------------------------------
# Sign parameters: {'n': 512, 'k': 2, 'l': 3, 'q': 130817, 'p': 0.3125, 'tau': 59, 'd': 9, 'B11': 23000, 't': 476.2480850631111}
# Bound for SIS: 31240.0625
# Public key size (bytes):  2208
# Signature size (bytes):   2633
# Sum size (bytes):         4841
# MLWE security:
# Primal & 1019 & 934 & 273 & 240 & 193
# Dual & 1024 & 922 & 269 & 236 & 191
# MSIS security:
# ...

# %%
# 512 bits 安全性参数

from math import sqrt
from Sign_estimate import *
from helper_pycode.repetitions_compute import * 
from helper_pycode.gamma_estimate import gamma_estimate
from helper_pycode.tau_compute import tau_computer

##############################################################
# 参数
n    =  1024        # 环的维数
k    =  2           # 矩阵 A 的参数（A的行数为  k ）
l    =  3           # 矩阵 A 的参数（A的列数为 l-1）
q    =  260609      # 模数
p    =  0.2        # 三元分布取 1（或-1）的概率
c_entropy = 513     # c 的信息熵大小
tau  =  tau_computer(n, c_entropy)
                    # c 的汉明重量（根据需要提前计算得到）
N    =  10000       # 估计 gamma 时的重复次数，N 越大估计越准确
rate =  [50]        # s 的通过率（可自由设定，仅可设定一个）
B11  =  80000       # 界的参数（其余的界由这个设定的计算得到）
d    =  10          # 压缩后的 比特 数

# 以上为可改动的参数！！！
##############################################################

print("512 bits security parameters:")
print("-------------------------------")

dim  = k + l        # s 的维数
num1 = int(n * p)   # 三元分布中 1（或-1）的个数

# gamma 和 Sc 的估计
gamma = gamma_estimate(N, n, num1, dim, tau, rate)[0]
t = float(gamma * sqrt(tau))
print(f"gamma          =  {gamma}")
print(f"tau            =  {tau}")
print(f"entropy of c   =  {c_entropy}")
print(f"bound of Sc    =  {t}")

print("-------------------------------")

# 相关的界
B     = from_B11_to_B(B11, n, k, l, q, d, t)
B0    = from_B11_to_B0(B11, n, k, l, q, d, t)
B1    = from_B11_to_B1(B11, n, k, l, q, d)
B_SIS = from_B11_to_BSIS(B11, n, k, l, q, d)
print(f"B11            =  {B11}")
print(f"B0             =  {B0}")
print(f"B1             =  {B1}")
print(f"B              =  {B}")
print(f"B_SIS          =  {B_SIS}")

print("-------------------------------")

# 采样次数
M_reject, M_compress, M = from_B11_to_M(B11, n, k, l, q, d, tau, t)
print(f"sk accept rate =  {rate[0]}")
print(f"M_reject       =  {M_reject}")
print(f"M_compress     =  {M_compress}")
print(f"M              =  {M}")

print("-------------------------------")

# 安全性 和 尺寸
try_parameter = SignParameters(n, k, l, q, p, tau, d, B11, t)
summarize_sign(try_parameter)
# Out:
# 512 bits security parameters:
# -------------------------------
# gamma          =  72.73630801065936
# tau            =  115
# entropy of c   =  513
# bound of Sc    =  780.0100049662655
# -------------------------------
# B11            =  80000
# B0             =  73426.12924467407
# B1             =  74202.03963995306
# B              =  74206.13924964034
# B_SIS          =  91607.90911413218
# -------------------------------
# sk accept rate =  50
# M_reject       =  2.653861394076836
# M_compress     =  1.2225880007448662
# M              =  3.2445790960383825
# -------------------------------
# Sign parameters: {'n': 1024, 'k': 2, 'l': 3, 'q': 260609, 'p': 0.2, 'tau': 115, 'd': 10, 'B11': 80000, 't': 780.0100049662655}
# Bound for SIS: 91607.90911413218
# Public key size (bytes):  4640
# Signature size (bytes):   5811
# Sum size (bytes):         10451
# MLWE security:
# Primal & 2038 & 1918 & 560 & 492 & 398
# Dual & 2041 & 1881 & 550 & 483 & 390
# MSIS security:
# ...
