# %%
# 128 bits 安全性参数

from helper_pycode.entropy_coordinate_refined_hyperball import refined_compute_f_table
# 参数
n    =  512         # 环的维数
k    =  1           # 矩阵 A 的参数（A的行数为  k ）
l    =  2           # 矩阵 A 的参数（A的列数为 l-1）

m = k + l

q    =  130817      # 模数
d    =  10          # 压缩后的 比特 数
B0   =  6328.43
B1   =  6546.76

(high_prob, _) = refined_compute_f_table(n, m, B1, B0, d, q)

negligible_threshold = 2**(-20)
significant_prob = [(i, p) for i, p in enumerate(high_prob) if p >= negligible_threshold]
print(f"\n不可忽略的概率(>= 2^-20): 总共{len(significant_prob)}个")
for compressed_val, prob in significant_prob:
    print(f"  {compressed_val} -> {prob*100:.12f}%")
# Out:
# 不可忽略的概率(>= 2^-20): 总共13个
#   0 -> 29.624341096210%
#   1 -> 22.618126858410%
#   2 -> 9.790894501962%
#   3 -> 2.413788249736%
#   4 -> 0.336659143923%
#   5 -> 0.027132892116%
#   6 -> 0.001198130876%
#   1018 -> 0.001198130876%
#   1019 -> 0.027132892116%
#   1020 -> 0.336659143923%
#   1021 -> 2.413788249736%
#   1022 -> 9.790894501962%
#   1023 -> 22.618126858410%

# %%
# 256 bits 安全性参数

from helper_pycode.entropy_coordinate_refined_hyperball import refined_compute_f_table
# 参数
n    =  512         # 环的维数
k    =  2           # 矩阵 A 的参数（A的行数为  k ）
l    =  3           # 矩阵 A 的参数（A的列数为 l-1）

m = k + l

q    =  130817      # 模数
d    =  9          # 压缩后的 比特 数

B0   =  18366.73
B1   =  18900.22

(high_prob, _) = refined_compute_f_table(n, m, B1, B0, d, q)

negligible_threshold = 2**(-20)
significant_prob = [(i, p) for i, p in enumerate(high_prob) if p >= negligible_threshold]
print(f"\n不可忽略的概率(>= 2^-20): 总共{len(significant_prob)}个")
for compressed_val, prob in significant_prob:
    print(f"  {compressed_val} -> {prob*100:.12f}%")
# Out:
# 不可忽略的概率(>= 2^-20): 总共15个
#   0 -> 26.716924209551%
#   1 -> 21.417186745101%
#   2 -> 10.860670097783%
#   3 -> 3.535394909181%
#   4 -> 0.724936351572%
#   5 -> 0.095128153826%
#   6 -> 0.007800817290%
#   7 -> 0.000407398166%
#   505 -> 0.000407398166%
#   506 -> 0.007800817290%
#   507 -> 0.095128153826%
#   508 -> 0.724936351572%
#   509 -> 3.535394909181%
#   510 -> 10.860670097783%
#   511 -> 21.417186745101%

# %%
# 512 bits 安全性参数

from helper_pycode.entropy_coordinate_refined_hyperball import refined_compute_f_table
# 参数
n    =  1024        # 环的维数
k    =  2           # 矩阵 A 的参数（A的行数为  k ）
l    =  3           # 矩阵 A 的参数（A的列数为 l-1）

m = k + l

q    =  260609      # 模数
d    =  10          # 压缩后的 比特 数

B0   =  73242.47
B1   =  74202.04

(high_prob, _) = refined_compute_f_table(n, m, B1, B0, d, q)

negligible_threshold = 2**(-20)
significant_prob = [(i, p) for i, p in enumerate(high_prob) if p >= negligible_threshold]
print(f"\n不可忽略的概率(>= 2^-20): 总共{len(significant_prob)}个")
for compressed_val, prob in significant_prob:
    print(f"  {compressed_val} -> {prob*100:.12f}%")
# Out:
# 不可忽略的概率(>= 2^-20): 总共39个
#   0 -> 9.785836317811%
#   1 -> 9.459950807459%
#   2 -> 8.680694363703%
#   3 -> 7.443789716786%
#   4 -> 6.059114581014%
#   5 -> 4.608661661581%
#   6 -> 3.327495439973%
#   7 -> 2.244768870306%
#   8 -> 1.437490680683%
#   9 -> 0.859993740964%
#   10 -> 0.488391062519%
#   11 -> 0.259075726014%
#   12 -> 0.130458205303%
#   13 -> 0.061350327762%
#   14 -> 0.027387475531%
#   15 -> 0.011415281966%
#   16 -> 0.004516637450%
#   17 -> 0.001668117371%
#   18 -> 0.000584839176%
#   19 -> 0.000191336115%
#   1005 -> 0.000191336115%
#   1006 -> 0.000584839176%
#   1007 -> 0.001668117371%
#   1008 -> 0.004516637450%
#   1009 -> 0.011415281966%
#   1010 -> 0.027387475531%
#   1011 -> 0.061350327762%
#   1012 -> 0.130458205303%
#   1013 -> 0.259075726014%
#   1014 -> 0.488391062519%
#   1015 -> 0.859993740964%
#   1016 -> 1.437490680683%
#   1017 -> 2.244768870306%
#   1018 -> 3.327495439973%
#   1019 -> 4.608661661581%
#   1020 -> 6.059114581014%
# ...
