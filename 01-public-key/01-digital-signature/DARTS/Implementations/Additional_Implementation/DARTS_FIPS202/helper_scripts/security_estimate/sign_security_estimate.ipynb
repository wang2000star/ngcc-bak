# %%
from SIS_estimate import *

# %% [markdown]
# ps.method = {l2, HAETAE_l2, refined_l2, linf}
#
#
# l2            :  Dilithum的2范数评估方法
# HAETAE_l2     :  HAETAE的2范数评估方法
# refined_l2    :  改进的2范数评估方法
# linf          :  无穷范数评估方法

# %%
# NTRU + Sign 参数1

q = 3329
n = 512
max_w = 1024
h = 512
B = 5471

print("refined HAETAE SIS l2 cost:",SIS_optimize_attack(q, max_w, h, B, cost_attack=refined_SIS_l2_cost, cost_svp=svp_classical, verbose=False))
print("Dilithum SIS l2 cost:",SIS_optimize_attack(q, max_w, h, B, cost_attack=Dilithum_SIS_l2_cost, cost_svp=svp_classical, verbose=False))
print("HAETAE SIS l2 cost:",SIS_optimize_attack(q, max_w, h, B, cost_attack=HAETAE_SIS_l2_cost, cost_svp=svp_classical, verbose=False))
# Out:
# refined HAETAE SIS l2 cost: (1024, 311, 91.20543372036278)
# Dilithum SIS l2 cost: (1024, 338, 98.85866262187535)
# HAETAE SIS l2 cost: (1024, 319, 93.30151886502436)

# %%
# NTRU + Sign 参数2

q = 7681
n = 512
max_w = 2048
h = 1024
B = 14128

print("refined HAETAE SIS l2 cost:",SIS_optimize_attack(q, max_w, h, B, cost_attack=refined_SIS_l2_cost, cost_svp=svp_classical, verbose=False))
print("Dilithum SIS l2 cost:",SIS_optimize_attack(q, max_w, h, B, cost_attack=Dilithum_SIS_l2_cost, cost_svp=svp_classical, verbose=False))
print("HAETAE SIS l2 cost:",SIS_optimize_attack(q, max_w, h, B, cost_attack=HAETAE_SIS_l2_cost, cost_svp=svp_classical, verbose=False))
# Out:
# refined HAETAE SIS l2 cost: (2048, 735, 214.98329467659045)
# Dilithum SIS l2 cost: (2048, 766, 224.04063777620274)
# HAETAE SIS l2 cost: (2048, 766, 224.04063777620274)

# %%
# HAETAE 参数120

q = 64513
n = 256
max_w = 6 * n
h = 2 * n
B = 12777

print("refined HAETAE SIS l2 cost:",SIS_optimize_attack(q, max_w, h, B, cost_attack=refined_SIS_l2_cost, cost_svp=svp_classical, verbose=False))
print("Dilithum SIS l2 cost:",SIS_optimize_attack(q, max_w, h, B, cost_attack=Dilithum_SIS_l2_cost, cost_svp=svp_classical, verbose=False))
print("HAETAE SIS l2 cost:",SIS_optimize_attack(q, max_w, h, B, cost_attack=HAETAE_SIS_l2_cost, cost_svp=svp_classical, verbose=False))
# Out:
# refined HAETAE SIS l2 cost: (1536, 405, 118.45490639603409)
# Dilithum SIS l2 cost: (1536, 405, 118.45490639603409)
# HAETAE SIS l2 cost: (1536, 405, 118.45490639603409)

# %%
# HAETAE 参数180

q = 64513
n = 256
max_w = 9 * n
h = 3 * n
B = 21906

print("refined HAETAE SIS l2 cost:",SIS_optimize_attack(q, max_w, h, B, cost_attack=refined_SIS_l2_cost, cost_svp=svp_classical, verbose=False))
print("Dilithum SIS l2 cost:",SIS_optimize_attack(q, max_w, h, B, cost_attack=Dilithum_SIS_l2_cost, cost_svp=svp_classical, verbose=False))
print("HAETAE SIS l2 cost:",SIS_optimize_attack(q, max_w, h, B, cost_attack=HAETAE_SIS_l2_cost, cost_svp=svp_classical, verbose=False))
# Out:
# refined HAETAE SIS l2 cost: (2304, 613, 179.2910064710343)
# Dilithum SIS l2 cost: (2304, 613, 179.2910064710343)
# HAETAE SIS l2 cost: (2304, 613, 179.2910064710343)

# %%
# HAETAE 参数260

q = 64513
n = 256
max_w = 11 * n
h = 4 * n
B = 24441

print("refined HAETAE SIS l2 cost:",SIS_optimize_attack(q, max_w, h, B, cost_attack=refined_SIS_l2_cost, cost_svp=svp_classical, verbose=False))
print("Dilithum SIS l2 cost:",SIS_optimize_attack(q, max_w, h, B, cost_attack=Dilithum_SIS_l2_cost, cost_svp=svp_classical, verbose=False))
print("HAETAE SIS l2 cost:",SIS_optimize_attack(q, max_w, h, B, cost_attack=HAETAE_SIS_l2_cost, cost_svp=svp_classical, verbose=False))
# Out:
# refined HAETAE SIS l2 cost: (2816, 878, 256.7985378165875)
# Dilithum SIS l2 cost: (2816, 878, 256.7985378165875)
# HAETAE SIS l2 cost: (2816, 878, 256.7985378165875)
